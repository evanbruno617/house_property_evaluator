# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import os
from sklearn.metrics import r2_score
import numpy as np

# %%
# read in median prices
housing = pd.read_csv('MedianPricesExisting.csv')
housing.head()
# Out:
#    Unnamed: 0        CA   Alameda    Amador          Butte      Calaveras  \
# 0         138  248354.0  410952.0       NaN  148094.833333            NaN
# 1         150  281332.0  394957.0       NaN  152630.947368  187999.600000
# 2         162  338836.0  453079.0       NaN  200000.000000  233927.892857
# 3         174  401720.0  491495.0       NaN  221969.257576  323529.176471
# 4         186  474270.0  604392.0  327777.5  276743.651163  343749.562500
#
#    Contra-Costa  Del Norte  El Dorado         Fresno  ...     Condo  \
# 0           NaN        NaN        NaN  106202.221519  ...  190240.0
# 1           NaN        NaN        NaN  128629.705479  ...  214100.0
# 2           NaN        NaN        NaN  150525.789474  ...  253560.0
# 3           NaN        NaN        NaN  198822.588235  ...  310050.0
# 4           NaN        NaN        NaN  248537.040936  ...  391050.0
#
#         LA Metro  Central Coast  Central Valley  Far North  Inland Empire  \
# ...

# %%
# read in median time

time = pd.read_csv('MedianTime.csv')
time.head()
# Out:
#    Unnamed: 0    CA    Alameda   Amador      Butte  Calaveras  Contra-Costa  \
# 0         134  33.7  18.692352      NaN        NaN        NaN     18.464986
# 1         146  34.9  24.995069      NaN        NaN        NaN     24.155039
# 2         158  28.1  23.019947      NaN        NaN        NaN     21.115607
# 3         170  26.7  20.735692      NaN  77.675000        NaN     21.102273
# 4         182  40.3  52.634921  50.9375  79.282609        NaN     47.163934
#
#    Del Norte  El Dorado     Fresno  ...  Condo   LA Metro  Central Coast  \
# 0        NaN        NaN        NaN  ...   28.0  32.350296           31.0
# 1        NaN        NaN  25.908929  ...   29.0  37.682888           58.0
# 2        NaN        NaN  22.366295  ...   30.0  28.516618           40.0
# 3        NaN        NaN  25.072423  ...   23.6  26.935140           33.0
# 4        NaN        NaN  23.789899  ...   31.7  36.764907           28.0
#
# ...

# %%
# get list of counties only

counties = housing.columns.tolist()[1:-4]

# %%
# remove county that does not match
counties.remove('S.F. Bay Area')

# %%
# get ratio of median prices to time on market

final_df = pd.DataFrame()

counties_df = {}

for county in counties:

    transfer_county = housing[[f'{county}', 'Year']]
    
    transfer_time = time[[f'{county}', 'Year']]
    
    data_df = pd.merge(transfer_county, transfer_time, on='Year')
    
    data_df['Ratio'] = data_df[f'{county}_x'] / data_df[f'{county}_y']
    
    
    counties_df[county] = data_df['Ratio'].tolist()

# %%
# make into dataframe

ratio_df = pd.DataFrame(counties_df)

# %%
ratio_df['Year'] = housing['Year'].tolist()

# %%
#export as csv
ratio_df.to_csv('Ratio_Change.csv')

# %%
ratio_df
# Out:
#           CA   Alameda    Amador     Butte  Calaveras  Contra-Costa  \
# 0        NaN       NaN       NaN       NaN        NaN           NaN
# 1   3.409176 -0.160606       NaN       NaN        NaN           NaN
# 2  -0.701303 -1.495123       NaN       NaN        NaN           NaN
# 3  -2.985382 -0.709524       NaN       NaN        NaN           NaN
# 4   0.453292  0.308218       NaN  9.761072        NaN           NaN
# 5   2.204320  3.176411  0.025931  1.924841        NaN           NaN
# 6   0.096069  0.006931 -0.047529 -0.291725        NaN           NaN
# 7   2.279654 -0.188855  0.716328 -0.310319        NaN     -0.435402
# 8   1.585663  1.242499 -0.499647  0.387303        NaN      0.777577
# 9  -0.245955 -0.299080  0.556214 -0.140536        NaN     -0.646147
# 10 -0.017445  0.030339  0.176485  0.076213        NaN     -0.070630
# 11 -4.591175  0.771795 -1.284248  0.609420        NaN      0.177860
# 12 -0.388720 -0.508452 -0.845988 -3.097540        NaN     -0.702416
# ...
