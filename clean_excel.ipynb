# %%
import pandas as pd

# %%
medianprices = pd.read_excel('MedianPricesofExistingDetachedHomesHistoricalData.xlsx')

# %%
medianprices.head(10)
# Out:
#   Median Price (existing single-family detached homes only)   \
# 0                                              *Note
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                             Mon-Yr
# 7                                1990-01-01 00:00:00
# 8                                1990-02-01 00:00:00
# 9                                1990-03-01 00:00:00
#
#                                           Unnamed: 1     Unnamed: 2  \
# 0  Sales for California are seasonally adjusted a...            NaN
# 1  LA Metro is a 5-county region that includes Lo...            NaN
# 2  Inland Empire includes Riverside County and Sa...            NaN
# 3  S.F. Bay Area has been redefined to include th...            NaN
# ...

# %%
# get rid of uncessary data

medianprices = medianprices.loc[medianprices.index > 5]

# %%
medianprices.head()
# Out:
#    Median Price (existing single-family detached homes only)  Unnamed: 1  \
# 6                                              Mon-Yr                 CA
# 7                                 1990-01-01 00:00:00             194952
# 8                                 1990-02-01 00:00:00             196273
# 9                                 1990-03-01 00:00:00             194856
# 10                                1990-04-01 00:00:00             196111
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7  \
# 6         Alameda     Amador      Butte  Calaveras  Contra-Costa  Del Norte
# 7   226148.902299        NaN  102142.75        NaN           NaN        NaN
# 8          219306        NaN      83333        NaN           NaN        NaN
# 9          225162        NaN     100000        NaN           NaN        NaN
# 10         229333        NaN   107999.6        NaN           NaN        NaN
#
# ...

# %%
# Get new name of columns

columns = medianprices.transpose()[6].tolist()

# %%
# get rid of uncessary names

medianprices = medianprices.loc[medianprices.index > 6]

medianprices.columns = columns

medianprices.head()
# Out:
#                  Mon-Yr      CA        Alameda Amador      Butte Calaveras  \
# 7   1990-01-01 00:00:00  194952  226148.902299    NaN  102142.75       NaN
# 8   1990-02-01 00:00:00  196273         219306    NaN      83333       NaN
# 9   1990-03-01 00:00:00  194856         225162    NaN     100000       NaN
# 10  1990-04-01 00:00:00  196111         229333    NaN   107999.6       NaN
# 11  1990-05-01 00:00:00  195281         232291    NaN     100000       NaN
#
#    Contra-Costa Del Norte El Dorado        Fresno  ... Yuba NaN   Condo  \
# 7           NaN       NaN       NaN     82083.125  ...  NaN NaN  141519
# 8           NaN       NaN       NaN   87186.78125  ...  NaN NaN  144965
# 9           NaN       NaN       NaN       83888.5  ...  NaN NaN  141132
# 10          NaN       NaN       NaN  85428.028571  ...  NaN NaN  145707
# 11          NaN       NaN       NaN     88749.125  ...  NaN NaN  146060
#
#          LA Metro Central Coast Central Valley Far North Inland Empire  \
# ...

# %%
# obtain only the year

medianprices['Year'] = medianprices['Mon-Yr'].apply(sep)

medianprices['Month'] = medianprices['Mon-Yr'].apply(month_sep)

medianprices.drop(columns='Mon-Yr', inplace=True)

# %%
def sep(i):
    year = i.year
    
    return year

# %%
def month_sep(i):
    month = i.month
    
    return month

# %%
#remove unecessary column
columns.remove('Mon-Yr')

# %%
# change data type to float

medianprices[columns] = medianprices[columns].astype(float)

# %%
medianprices
# Out:
#            CA       Alameda    Amador      Butte  Calaveras  Contra-Costa  \
# 7    194952.0  2.261489e+05       NaN  102142.75        NaN           NaN
# 8    196273.0  2.193060e+05       NaN   83333.00        NaN           NaN
# 9    194856.0  2.251620e+05       NaN  100000.00        NaN           NaN
# 10   196111.0  2.293330e+05       NaN  107999.60        NaN           NaN
# 11   195281.0  2.322910e+05       NaN  100000.00        NaN           NaN
# ..        ...           ...       ...        ...        ...           ...
# 403  751330.0  1.065000e+06  422500.0  410000.00   455000.0      736500.0
# 404  735480.0  1.100000e+06  429500.0  405000.00   437500.0      760000.0
# 405  791490.0  1.225000e+06  414940.0  421650.00   438000.0      852500.0
# 406  811950.0  1.225000e+06  475000.0  469000.00   495000.0      900000.0
# 407  836110.0  1.260000e+06  449000.0  436950.00   550000.0      888000.0
#
#      Del Norte  El Dorado         Fresno     Glenn  ...     Condo  \
# ...

# %%
# obtain data from each year
medianprices = medianprices.loc[(medianprices['Year'] >= 2000) & (medianprices['Month'] == 12)]

# %%
medianprices.loc[medianprices['Year'] == 2022][column].isnull().count()
# Out:
# 12

# %%
column
# Out:
# 'SoCal'

# %%
# obtain data from each year
medianprices = medianprices.loc[(medianprices['Year'] >= 2000)]

years = medianprices['Year'].unique().tolist()

data = {}

for column in columns:
    data[column] = []

for column in columns:
    for year in years:
        if medianprices.loc[medianprices['Year'] == year][column].isnull().count() < 12:
            data[column].append(np.nan)
            
            continue
        
        total = medianprices.loc[medianprices['Year'] == year][column].sum()
        
        data[column].append(total)
        
data_df = pd.DataFrame(data)

data_df['Year'] = years

# export cleaned file as csv

data_df.to_csv('MedianPricesExisting.csv')

# %%
# export cleaned file as csv

medianprices.to_csv('MedianPricesExisting.csv')

# %%
mediantime = pd.read_excel('MedianTimeonMarketofExistingDetachedHomesHistoricalData.xlsx')
mediantime.head()
# Out:
#                         Median Time On Market (Days) Unnamed: 1 Unnamed: 2  \
# 0  OC data has been refined to avoid double count...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                             Mon-Yr         CA    Alameda
# 3                                1990-01-01 00:00:00         62  50.655556
# 4                                1990-02-01 00:00:00         64  53.275362
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN           NaN        NaN        NaN
# 1        NaN        NaN        NaN           NaN        NaN        NaN
# 2     Amador      Butte  Calaveras  Contra-Costa  Del Norte  El Dorado
# 3        NaN        NaN        NaN     39.662338        NaN        NaN
# 4        NaN        NaN        NaN     38.440789        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55  \
# ...

# %%
# get rid of uncessary data

mediantime = mediantime.loc[mediantime.index > 1]

mediantime.head()
# Out:
#   Median Time On Market (Days) Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2                       Mon-Yr         CA    Alameda     Amador      Butte
# 3          1990-01-01 00:00:00         62  50.655556        NaN        NaN
# 4          1990-02-01 00:00:00         64  53.275362        NaN        NaN
# 5          1990-03-01 00:00:00         60  49.824561        NaN        NaN
# 6          1990-04-01 00:00:00         58  53.509524        NaN        NaN
#
#   Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 52  \
# 2  Calaveras  Contra-Costa  Del Norte  El Dorado     Fresno  ...        Yuba
# 3        NaN     39.662338        NaN        NaN        NaN  ...         NaN
# 4        NaN     38.440789        NaN        NaN        NaN  ...         NaN
# 5        NaN     31.922727        NaN        NaN        NaN  ...         NaN
# 6        NaN     31.769912        NaN        NaN        NaN  ...         NaN
#
# ...

# %%
# Get new name of columns

columns = mediantime.transpose()[2].tolist()

# get rid of uncessary names

mediantime = mediantime.loc[mediantime.index > 2]

mediantime.columns = columns

mediantime.head()
# Out:
#                 Mon-Yr  CA    Alameda Amador Butte Calaveras Contra-Costa  \
# 3  1990-01-01 00:00:00  62  50.655556    NaN   NaN       NaN    39.662338
# 4  1990-02-01 00:00:00  64  53.275362    NaN   NaN       NaN    38.440789
# 5  1990-03-01 00:00:00  60  49.824561    NaN   NaN       NaN    31.922727
# 6  1990-04-01 00:00:00  58  53.509524    NaN   NaN       NaN    31.769912
# 7  1990-05-01 00:00:00  60  47.345455    NaN   NaN       NaN       33.625
#
#   Del Norte El Dorado Fresno  ... Yuba NaN Condo   LA Metro Central Coast  \
# 3       NaN       NaN    NaN  ...  NaN NaN    52  66.994178           NaN
# 4       NaN       NaN    NaN  ...  NaN NaN    55  68.129967           NaN
# 5       NaN       NaN    NaN  ...  NaN NaN    51  63.150718           NaN
# 6       NaN       NaN    NaN  ...  NaN NaN    51  61.840828           NaN
# 7       NaN       NaN    NaN  ...  NaN NaN    53  63.623355           NaN
#
#   Central Valley Far North Inland Empire SF Bay Area SoCal
# ...

# %%
# obtain only the year

mediantime['Year'] = mediantime['Mon-Yr'].apply(sep)

mediantime['Month'] = mediantime['Mon-Yr'].apply(month_sep)

mediantime.drop(columns='Mon-Yr', inplace=True)

#remove unecessary column
columns.remove('Mon-Yr')

mediantime[columns] = mediantime[columns].apply(lambda x: x.replace('n.a.', 0))


# change data type to float

mediantime[columns] = mediantime[columns].astype(float)

# %%
import numpy as np

# %%
# obtain data from each year
mediantime = mediantime.loc[(mediantime['Year'] >= 2000)]

years = mediantime['Year'].unique().tolist()

data = {}

for column in columns:
    data[column] = []

for column in columns:
    for year in years:
        
        if mediantime.loc[mediantime['Year'] == year][column].isnull().count() < 12:
            data[column].append(np.nan)
            
            continue
        total = mediantime.loc[mediantime['Year'] == year][column].mean()
        
        data[column].append(total)
        
data_df = pd.DataFrame(data)

data_df['Year'] = years

# export cleaned file as csv

data_df.to_csv('MedianTime.csv')

# %%
# obtain data from each year
mediantime = mediantime.loc[(mediantime['Year'] >= 2000) & (mediantime['Month'] == 12)]

mediantime.to_csv('MedianTime.csv')

# %%
mediantime = pd.read_excel('PercentChangeofSalesofExistingDetachedHomesHistoricalData.xlsx')
mediantime.head(10)
# Out:
#   Percent Change of Sales of Existing Single-Family Homes (Month-to-Month)  \
# 0                                              *Note
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                             Mon-Yr
# 7                                1990-01-01 00:00:00
# 8                                1990-02-01 00:00:00
# 9                                1990-03-01 00:00:00
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0  Sales for California are seasonally adjusted a...        NaN        NaN
# 1  LA Metro is a 5-county region that includes Lo...        NaN        NaN
# 2  Inland Empire includes Riverside County and Sa...        NaN        NaN
# ...

# %%
# get rid of uncessary data

mediantime = mediantime.loc[mediantime.index > 5]

mediantime.head()
# Out:
#    Percent Change of Sales of Existing Single-Family Homes (Month-to-Month)  \
# 6                                              Mon-Yr
# 7                                 1990-01-01 00:00:00
# 8                                 1990-02-01 00:00:00
# 9                                 1990-03-01 00:00:00
# 10                                1990-04-01 00:00:00
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5    Unnamed: 6  \
# 6         CA*    Alameda     Amador      Butte  Calaveras  Contra-Costa
# 7         NaN        NaN        NaN        NaN        NaN           NaN
# 8   -0.017694        NaN        NaN  -0.677966        NaN     -0.065972
# 9   -0.110365   0.580214        NaN   0.263158        NaN      0.780669
# 10  -0.054121  -0.011844        NaN     -0.375        NaN     -0.066806
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 52 Unnamed: 53 Unnamed: 54  \
# 6   Del Norte  El Dorado     Fresno  ...        Yuba         NaN       Condo
# ...

# %%
# Get new name of columns

columns = mediantime.transpose()[6].tolist()

# get rid of uncessary names

mediantime = mediantime.loc[mediantime.index > 6]

mediantime.columns = columns

mediantime.head()
# Out:
#                  Mon-Yr       CA*   Alameda Amador     Butte Calaveras  \
# 7   1990-01-01 00:00:00       NaN       NaN    NaN       NaN       NaN
# 8   1990-02-01 00:00:00 -0.017694       NaN    NaN -0.677966       NaN
# 9   1990-03-01 00:00:00 -0.110365  0.580214    NaN  0.263158       NaN
# 10  1990-04-01 00:00:00 -0.054121 -0.011844    NaN    -0.375       NaN
# 11  1990-05-01 00:00:00 -0.036446  0.085616    NaN  0.533333       NaN
#
#    Contra-Costa Del Norte El Dorado    Fresno  ... Yuba NaN Condo  LA Metro  \
# 7           NaN       NaN       NaN       NaN  ...  NaN NaN   NaN       NaN
# 8     -0.065972       NaN       NaN  0.163366  ...  NaN NaN   NaN -0.039812
# 9      0.780669       NaN       NaN  0.093617  ...  NaN NaN   NaN  0.231572
# 10    -0.066806       NaN       NaN  0.159533  ...  NaN NaN   NaN -0.042863
# 11    -0.040268       NaN       NaN  0.127517  ...  NaN NaN   NaN  0.173871
#
#    Central Coast Central Valley Far North Inland Empire S.F. Bay Area  \
# ...

# %%
# obtain only the year

mediantime['Year'] = mediantime['Mon-Yr'].apply(sep)

mediantime['Month'] = mediantime['Mon-Yr'].apply(month_sep)

mediantime.drop(columns='Mon-Yr', inplace=True)

#remove unecessary column
columns.remove('Mon-Yr')

mediantime[columns] = mediantime[columns].apply(lambda x: x.replace('n.a.', 0))


# change data type to float

mediantime[columns] = mediantime[columns].astype(float)

# %%
# obtain data from each year
mediantime = mediantime.loc[(mediantime['Year'] >= 2000)]

years = mediantime['Year'].unique().tolist()

data = {}

for column in columns:
    data[column] = []

for column in columns:
    for year in years:
        
        if mediantime.loc[mediantime['Year'] == year][column].isnull().count() < 12:
            data[column].append(np.nan)
            
            continue
        total = mediantime.loc[mediantime['Year'] == year][column].sum()
        
        data[column].append(total)
        
data_df = pd.DataFrame(data)

data_df['Year'] = years

# export cleaned file as csv

data_df.to_csv('PercentChangeSales.csv')

# %%
# obtain data from each year
mediantime = mediantime.loc[(mediantime['Year'] >= 2000) & (mediantime['Month'] == 12)]

mediantime.to_csv('PercentChangeSales.csv')

# %%
mediantime = pd.read_excel('UnsoldInventoryIndexofExistingDetachedHomesHistoricalData.xlsx')
mediantime.head(12)
# Out:
#    Unsold Inventory Index (right axis)  \
# 0               Unsold Inventory Index
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                              Mon-Yr
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2   LA historical data has been revised going back...        NaN        NaN
# 3   OC data has been refined to avoid double count...        NaN        NaN
# ...

# %%
# get rid of uncessary data

mediantime = mediantime.loc[mediantime.index > 10]

mediantime.head()
# Out:
#    Unsold Inventory Index (right axis) Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 11                              Mon-Yr         CA    Alameda     Amador
# 12                 1990-01-01 00:00:00       10.7   11.71831        NaN
# 13                 1990-02-01 00:00:00       12.9  13.198582        NaN
# 14                 1990-03-01 00:00:00        9.8   8.964912        NaN
# 15                 1990-04-01 00:00:00       10.8  10.286052        NaN
#
#    Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 11      Butte  Calaveras  Contra-Costa  Del Norte  El Dorado     Fresno  ...
# 12        NaN        NaN           8.2        NaN        NaN        NaN  ...
# 13        NaN        NaN           9.8        NaN        NaN        NaN  ...
# 14        NaN        NaN           6.8        NaN        NaN        NaN  ...
# 15        NaN        NaN           8.1        NaN        NaN        NaN  ...
#
#    Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55    Unnamed: 56  \
# ...

# %%
# Get new name of columns

columns = mediantime.transpose()[11].tolist()

# get rid of uncessary names

mediantime = mediantime.loc[mediantime.index > 11]

mediantime.columns = columns

mediantime.head()
# Out:
#                  Mon-Yr    CA    Alameda Amador Butte Calaveras Contra-Costa  \
# 12  1990-01-01 00:00:00  10.7   11.71831    NaN   NaN       NaN          8.2
# 13  1990-02-01 00:00:00  12.9  13.198582    NaN   NaN       NaN          9.8
# 14  1990-03-01 00:00:00   9.8   8.964912    NaN   NaN       NaN          6.8
# 15  1990-04-01 00:00:00  10.8  10.286052    NaN   NaN       NaN          8.1
# 16  1990-05-01 00:00:00  10.5   9.877593    NaN   NaN       NaN          9.4
#
#    Del Norte El Dorado Fresno  ... Yuba NaN Condo   LA Metro Central Coast  \
# 12       NaN       NaN    NaN  ...  NaN NaN   8.1  14.015311           NaN
# 13       NaN       NaN    NaN  ...  NaN NaN   9.4  18.614268           NaN
# 14       NaN       NaN    NaN  ...  NaN NaN   6.5  15.168962           NaN
# 15       NaN       NaN    NaN  ...  NaN NaN   7.5  15.840659           NaN
# 16       NaN       NaN    NaN  ...  NaN NaN   7.2  15.125104           NaN
#
# ...

# %%
# obtain only the year

mediantime['Year'] = mediantime['Mon-Yr'].apply(sep)

mediantime['Month'] = mediantime['Mon-Yr'].apply(month_sep)

mediantime.drop(columns='Mon-Yr', inplace=True)

#remove unecessary column
columns.remove('Mon-Yr')

mediantime[columns] = mediantime[columns].apply(lambda x: x.replace('n.a.', 0))


# change data type to float

mediantime[columns] = mediantime[columns].astype(float)

# %%
# obtain data from each year
mediantime = mediantime.loc[(mediantime['Year'] >= 2000) & (mediantime['Month'] == 12)]

mediantime.to_csv('UnsoldInventory.csv')

# %%
# obtain data from each year
mediantime = mediantime.loc[(mediantime['Year'] >= 2000)]

years = mediantime['Year'].unique().tolist()

data = {}

for column in columns:
    data[column] = []

for column in columns:
    for year in years:
        
        if mediantime.loc[mediantime['Year'] == year][column].isnull().count() < 12:
            data[column].append(np.nan)
            
            continue
        total = mediantime.loc[mediantime['Year'] == year][column].mean()
        
        data[column].append(total)
        
data_df = pd.DataFrame(data)

data_df['Year'] = years

# export cleaned file as csv
data_df.to_csv('UnsoldInventory.csv')
